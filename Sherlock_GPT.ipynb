# %% [markdown]
# <a href="https://colab.research.google.com/github/eranga-de-saa/Sherlock_GPT/blob/main/Sherlock_GPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade kagglehub
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2025.8.3)

# %%
import kagglehub
import zipfile, glob, os, shutil

# Optional: login if running outside Kaggle (this may prompt or use env vars)
# kagglehub.login()

# Download latest version of the dataset
path = kagglehub.dataset_download("bengiefigueroa/sherlock-holmes-complete-collection")
print("Downloaded to:", path)

# kagglehub may return a directory path or a zip path. Handle both:
download_dir = None
if path.endswith('.zip'):
    extract_dir = "sherlock_raw"
    with zipfile.ZipFile(path, 'r') as z:
        z.extractall(extract_dir)
    download_dir = extract_dir
else:
    # sometimes kagglehub returns a directory
    download_dir = path

# find all .txt files inside the download_dir
txt_files = []
for root, _, files in os.walk(download_dir):
    for f in files:
        if f.lower().endswith('.txt'):
            txt_files.append(os.path.join(root, f))

print("Found text files:", len(txt_files))

# concatenate into input.txt (utf-8)
with open('input.txt', 'w', encoding='utf-8') as fout:
    for fname in txt_files:
        with open(fname, 'r', encoding='utf-8', errors='ignore') as fin:
            fout.write(fin.read())
            fout.write("\n\n")  # separate files

print("Created input.txt (size: {:.2f} MB)".format(os.path.getsize('input.txt')/1024/1024))
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/bengiefigueroa/sherlock-holmes-complete-collection?dataset_version_number=1...
# 100%|██████████| 1.44M/1.44M [00:00<00:00, 39.1MB/s]
# Extracting files...
# Downloaded to: /root/.cache/kagglehub/datasets/bengiefigueroa/sherlock-holmes-complete-collection/versions/1
# Found text files: 60
# Created input.txt (size: 3.68 MB)

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.213728 M parameters
# step 0: train loss 4.6940, val loss 4.6909
# step 100: train loss 2.5005, val loss 2.4924
# step 200: train loss 2.3126, val loss 2.3018
# step 300: train loss 2.2368, val loss 2.2350
# step 400: train loss 2.1937, val loss 2.1936
# step 500: train loss 2.1195, val loss 2.1222
# step 600: train loss 2.0724, val loss 2.0727
# step 700: train loss 2.0080, val loss 2.0040
# step 800: train loss 1.9637, val loss 1.9604
# step 900: train loss 1.9426, val loss 1.9509
# step 1000: train loss 1.9035, val loss 1.9052
# step 1100: train loss 1.8788, val loss 1.8749
# step 1200: train loss 1.8610, val loss 1.8658
# step 1300: train loss 1.8338, val loss 1.8252
# step 1400: train loss 1.8226, val loss 1.8229
# step 1500: train loss 1.8185, val loss 1.8028
# step 1600: train loss 1.8006, val loss 1.7994
# step 1700: train loss 1.7698, val loss 1.7717
# step 1800: train loss 1.7714, val loss 1.7632
# step 1900: train loss 1.7568, val loss 1.7592
# step 2000: train loss 1.7386, val loss 1.7332
# step 2100: train loss 1.7276, val loss 1.7205
# step 2200: train loss 1.7093, val loss 1.7134
# step 2300: train loss 1.7161, val loss 1.7093
# step 2400: train loss 1.7124, val loss 1.7087
# step 2500: train loss 1.6923, val loss 1.6837
# step 2600: train loss 1.6951, val loss 1.6878
# step 2700: train loss 1.6713, val loss 1.6672
# step 2800: train loss 1.6621, val loss 1.6687
# step 2900: train loss 1.6706, val loss 1.6603
# step 3000: train loss 1.6612, val loss 1.6486
# step 3100: train loss 1.6399, val loss 1.6494
# step 3200: train loss 1.6323, val loss 1.6365
# step 3300: train loss 1.6509, val loss 1.6451
# step 3400: train loss 1.6245, val loss 1.6336
# step 3500: train loss 1.6461, val loss 1.6384
# step 3600: train loss 1.6231, val loss 1.6248
# step 3700: train loss 1.6166, val loss 1.6144
# step 3800: train loss 1.6130, val loss 1.6083
# step 3900: train loss 1.6085, val loss 1.6089
# step 4000: train loss 1.6010, val loss 1.6018
# step 4100: train loss 1.5968, val loss 1.5887
# step 4200: train loss 1.5945, val loss 1.5979
# step 4300: train loss 1.5887, val loss 1.5852
# step 4400: train loss 1.5855, val loss 1.5615
# step 4500: train loss 1.5854, val loss 1.5813
# step 4600: train loss 1.5674, val loss 1.5721
# step 4700: train loss 1.5821, val loss 1.5644
# step 4800: train loss 1.5737, val loss 1.5667
# step 4900: train loss 1.5730, val loss 1.5646
# step 4999: train loss 1.5602, val loss 1.5693
#
#      morner
#      roning of the
#      this monone to Considession framine eachif booking recome, back poht that in runnerike some inworke Thalk buse at him.
#
#      "With do it inquester bush edint, but as of srecay this charnem fiet of only goimarda. Own all ejight was sometnaring reather
#      in throuble man few minally, the nimpsict in the itsure dame
#      was on his nace way most of them-hopselang silies has Dossiboluty."
#
#      "What not point," said the iselefor to all conportyined of
#      therper as mist throughts the charder
#      shed the mismare night coming."
#
#      I have books in
#      fink of yourselfs more which day well home of lighsing it. goes preaph sinch--morning."
#
#      "Well, you my to may machous atquite. "When I was I said cienterved we morve not hours
#      examing. Thought pomile hatweverly gaurous of
#      our even
#      gues of out me just this prienficeed the teir way a inatce orithates at weemarks, and was a revaly of the caughtom his opetickented of lay.
#
#      "Whith upe."
#
#      "He say, sme voice misself to nightle an the luttined itzen up with all nearry genturp which had bewills, but windone ny ground abt of
#      will narg9 and evillele to the waiting of
#      wood on or finder a oncluikhe your plachion he for
#      do untients then
#      which doing?"
#
#      "I point you undentied bute, but my said ve your comp. shope is condect. "He wils rittle dome.
#
#      "It we plane that in room heave."
#
#      "I had be Holmes, father of the tomight of wy hards famed a
#      propoopt cryfult a thinglems room
#      learged leanoring been loosing."
#
#      "I ush hit
#       will again was no?"
#
#      "Well, the smack six winherly four must well, be of weilt. I are the divert.
#
#      Holmethole
#      last wee has rawing are every accitoran him yeceart's at
#      looked of my old poapitor througe pach you six, for humon that's over reme to him. "It's get that outh heapley aposon hould be wealk werthing phape my hands intervichin of with the compled a liven to rusinate

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 32 # how many independent sequences will we process in parallel?
block_size = 64 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.215776 M parameters
# step 0: train loss 4.6366, val loss 4.6373
# step 100: train loss 2.4851, val loss 2.4817
# step 200: train loss 2.2974, val loss 2.2940
# step 300: train loss 2.2370, val loss 2.2340
# step 400: train loss 2.1835, val loss 2.1835
# step 500: train loss 2.1124, val loss 2.1196
# step 600: train loss 2.0343, val loss 2.0368
# step 700: train loss 1.9700, val loss 1.9708
# step 800: train loss 1.9203, val loss 1.9178
# step 900: train loss 1.8713, val loss 1.8650
# step 1000: train loss 1.8419, val loss 1.8332
# step 1100: train loss 1.8099, val loss 1.8023
# step 1200: train loss 1.7876, val loss 1.7800
# step 1300: train loss 1.7516, val loss 1.7485
# step 1400: train loss 1.7344, val loss 1.7339
# step 1500: train loss 1.7242, val loss 1.7181
# step 1600: train loss 1.6950, val loss 1.6863
# step 1700: train loss 1.6695, val loss 1.6618
# step 1800: train loss 1.6710, val loss 1.6672
# step 1900: train loss 1.6451, val loss 1.6415
# step 2000: train loss 1.6258, val loss 1.6249
# step 2100: train loss 1.6155, val loss 1.6090
# step 2200: train loss 1.6057, val loss 1.6070
# step 2300: train loss 1.5923, val loss 1.5842
# step 2400: train loss 1.5777, val loss 1.5783
# step 2500: train loss 1.5750, val loss 1.5729
# step 2600: train loss 1.5635, val loss 1.5634
# step 2700: train loss 1.5571, val loss 1.5628
# step 2800: train loss 1.5464, val loss 1.5429
# step 2900: train loss 1.5365, val loss 1.5341
# step 3000: train loss 1.5397, val loss 1.5341
# step 3100: train loss 1.5233, val loss 1.5231
# step 3200: train loss 1.5176, val loss 1.5198
# step 3300: train loss 1.5116, val loss 1.5153
# step 3400: train loss 1.5115, val loss 1.5116
# step 3500: train loss 1.4929, val loss 1.5013
# step 3600: train loss 1.4917, val loss 1.5027
# step 3700: train loss 1.4900, val loss 1.4810
# step 3800: train loss 1.4819, val loss 1.4823
# step 3900: train loss 1.4740, val loss 1.4793
# step 4000: train loss 1.4747, val loss 1.4748
# step 4100: train loss 1.4668, val loss 1.4729
# step 4200: train loss 1.4661, val loss 1.4695
# step 4300: train loss 1.4575, val loss 1.4616
# step 4400: train loss 1.4552, val loss 1.4652
# step 4500: train loss 1.4515, val loss 1.4492
# step 4600: train loss 1.4487, val loss 1.4552
# step 4700: train loss 1.4389, val loss 1.4444
# step 4800: train loss 1.4373, val loss 1.4453
# step 4900: train loss 1.4412, val loss 1.4475
# step 4999: train loss 1.4321, val loss 1.4391
#
#      one of he horsnight shade
#      the Poono-loombe,' neever? Off the only affbacting real Lostants that
#      your notiking to reworter the ginstazme. Rovert Streetered in a silshes besided at
#      allow, recaused had truth fiendow, to wound Ifpection. I ejight began over a
#      done-besined old nobit mind. Efind the strucke of the window. "I darked
#      wife-a his nace, and out or to more in a gostleman, sittran old
#      notifishingnerved to darked to to Mr. Watson my contrage as to you attently
#      with this throt he haved between with to two revortless bick."
#
#      I happeaneds in his being old not, answered the picketed a horded.
#
#      "It's he suspread, since-droad murdeded in them from my Formarrm,
#      anquited to be see to the stairst over we morst not ago, which examing
#      is to me dead will in the chap opened."
#
#      "Pramouse and but mery dog side with to earther gin to the ratce or of
#      the everished the hugged al dog to that might, even the rime so old object
#      the certain far a trattes. There here som to nightle an to do. His
#      her told gone, a shry gentuded. I phickst with in itsemed or ny
#      with to lettering bearm9 and eyes illed to strange ling has peope on or find
#      is time to me plach of they triough Lount joting the selingts instant colock. I think this in that
#      is, notimicative that I had should eached, and there striefly doman
#      barked setsidencly goir Stakems. In excessed, etexcence, no atturn,
#      to it is proysibless a very truth. I topting, for a thinglems room
#      there gollance communations to singuly you can two go this road of in lises; al
#      patctents! with I such him four must me had evertues to see the
#      stake, and alreath his close senst obved all that her oblacy to an atterly of
#      the splotter of my older afairst try!"
#
#      "Is is the looke a back sendaged me to his wanted me were have sunable. I should to
#      this werre us peling you naty to refeling the sraw, and the dealy undeerr him to

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 64 # how many independent sequences will we process in parallel?
block_size = 128 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.219872 M parameters
# step 0: train loss 4.6861, val loss 4.6859
# step 100: train loss 2.5195, val loss 2.5147
# step 200: train loss 2.3244, val loss 2.3215
# step 300: train loss 2.2550, val loss 2.2543
# step 400: train loss 2.2095, val loss 2.2077
# step 500: train loss 2.1289, val loss 2.1294
# step 600: train loss 2.0360, val loss 2.0328
# step 700: train loss 1.9408, val loss 1.9374
# step 800: train loss 1.8730, val loss 1.8688
# step 900: train loss 1.8111, val loss 1.8103
# step 1000: train loss 1.7651, val loss 1.7631
# step 1100: train loss 1.7243, val loss 1.7248
# step 1200: train loss 1.6897, val loss 1.6895
# step 1300: train loss 1.6594, val loss 1.6584
# step 1400: train loss 1.6290, val loss 1.6292
# step 1500: train loss 1.6091, val loss 1.6061
# step 1600: train loss 1.5896, val loss 1.5885
# step 1700: train loss 1.5705, val loss 1.5696
# step 1800: train loss 1.5481, val loss 1.5454
# step 1900: train loss 1.5299, val loss 1.5302
# step 2000: train loss 1.5253, val loss 1.5253
# step 2100: train loss 1.5085, val loss 1.5078
# step 2200: train loss 1.4955, val loss 1.4971
# step 2300: train loss 1.4812, val loss 1.4816
# step 2400: train loss 1.4687, val loss 1.4744
# step 2500: train loss 1.4648, val loss 1.4665
# step 2600: train loss 1.4521, val loss 1.4569
# step 2700: train loss 1.4493, val loss 1.4475
# step 2800: train loss 1.4336, val loss 1.4407
# step 2900: train loss 1.4298, val loss 1.4361
# step 3000: train loss 1.4186, val loss 1.4246
# step 3100: train loss 1.4164, val loss 1.4202
# step 3200: train loss 1.4068, val loss 1.4113
# step 3300: train loss 1.4020, val loss 1.4082
# step 3400: train loss 1.4062, val loss 1.4078
# step 3500: train loss 1.3920, val loss 1.3952
# step 3600: train loss 1.3861, val loss 1.3951
# step 3700: train loss 1.3820, val loss 1.3889
# step 3800: train loss 1.3828, val loss 1.3874
# step 3900: train loss 1.3712, val loss 1.3767
# step 4000: train loss 1.3723, val loss 1.3723
# step 4100: train loss 1.3653, val loss 1.3713
# step 4200: train loss 1.3545, val loss 1.3623
# step 4300: train loss 1.3555, val loss 1.3621
# step 4400: train loss 1.3536, val loss 1.3598
# step 4500: train loss 1.3456, val loss 1.3537
# step 4600: train loss 1.3476, val loss 1.3590
# step 4700: train loss 1.3421, val loss 1.3495
# step 4800: train loss 1.3473, val loss 1.3577
# step 4900: train loss 1.3393, val loss 1.3451
# step 4999: train loss 1.3370, val loss 1.3461
#
#      one of he horse should exchand. He stood-dood Co, Genner? Of are
#      that I should come, back. The charming we are atsom
#      were the ground!"
#
#      "I sure thought," said he, Holmes. "I wind alood, recourse inch in
#      those to would I pussed alther. High I should be the door-bess willle
#      to me. Even ally, the nempsicibility. We fread?"
#
#      "I
#             They most orgephone the and simple other cours problises if
#      not point," said that I might to alrge to
#      say, and attaweled as my writch coppet her sone out. I wanted one
#      come, cruncle a life and pointed, it it was percots. The estable
#      in questager, possibles, now overs?"
#
#      I had too a murdered, letter from my Faile?"
#
#      "Thousand, Watson, sir, I shall play we were burning against he examing
#      outlate it the question thousan?"
#
#      "This clear such of the meen dog out twich to earth me in the cairat.
#      Hateurs with arms, anyhow under alte broad back momence one.
#
#      He sall been what alther, that if arratidary me voin. Anyhold to
#      round the vulling with arridly chald nearry went drew in him.
#
#      "There was you note milliabt of the
#      bear 9 and eyelly?"
#
#      "Then illodgen the of the rest?"
#
#      "Well, if well form Streets Witerl Lours job, then the assure."
#
#      "I wanced the most up to be chare, but my from ally actuall. I wanted
#      face there strict from in
#         Phedap Indery, sir, it.  Cold by we assurfact a Hour went to one
#      to it used to Fergson! The porbod. The punished to
#      more groat there, and glal not more any should. Not I have can
#      to this light on the spearars, at an the she lessemen, for
#      the grove and one weilliar of the contrate,
#      alreath visitle last we chest alrate. One to lack to an afterly of
#     ten as looned over his spare. I was alternating soul. The house
#      as heard, an hour has were arratest outral able at once.
#      Alswer Polor friend.
#
#      "For you got chil do wing."
#
#     "Yes, y," I will chill, then.
